# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 204, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 204 (delta 47), reused 60 (delta 41), pack-reused 128
# Receiving objects: 100% (204/204), 8.42 MiB | 26.06 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# Answers:
# 1. I would say around 50-60 capacity (hidden units per layer)
# 2. I would say at around 20-30 capacity
# 3. I would say at around 65-75 capacity

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.304259, train error 89.00,  test loss 2.300280, test error 88.05
# Epoch   100, train loss 1.916825, train error 71.72,  test loss 1.761227, test error 70.62
# Epoch   200, train loss 1.904761, train error 70.85,  test loss 1.728260, test error 68.12
# Epoch   300, train loss 1.903895, train error 70.82,  test loss 1.724934, test error 68.75
# Epoch   400, train loss 1.903451, train error 72.12,  test loss 1.728203, test error 68.15
# Epoch   500, train loss 1.900619, train error 70.68,  test loss 1.727706, test error 68.32
# Epoch   600, train loss 1.903313, train error 71.32,  test loss 1.733375, test error 68.88
# Epoch   700, train loss 1.900710, train error 70.43,  test loss 1.724554, test error 67.93
# Epoch   800, train loss 1.902102, train error 70.60,  test loss 1.722729, test error 67.93
# Epoch   900, train loss 1.902241, train error 70.35,  test loss 1.721188, test error 68.43
# Training model with   4 hidden variables
# Epoch     0, train loss 2.292780, train error 87.60,  test loss 2.294007, test error 88.62
# Epoch   100, train loss 1.863251, train error 68.22,  test loss 1.729946, test error 67.12
# Epoch   200, train loss 1.809250, train error 66.78,  test loss 1.673097, test error 64.45
# Epoch   300, train loss 1.778984, train error 64.65,  test loss 1.636290, test error 63.83
# Epoch   400, train loss 1.774751, train error 64.78,  test loss 1.630783, test error 63.40
# Epoch   500, train loss 1.763262, train error 64.22,  test loss 1.623617, test error 63.25
# Epoch   600, train loss 1.761974, train error 63.60,  test loss 1.630489, test error 63.45
# Epoch   700, train loss 1.736612, train error 63.25,  test loss 1.575616, test error 61.38
# Epoch   800, train loss 1.730187, train error 63.40,  test loss 1.560897, test error 60.50
# Epoch   900, train loss 1.727268, train error 62.00,  test loss 1.566799, test error 59.53
# Training model with   6 hidden variables
# Epoch     0, train loss 2.300732, train error 89.25,  test loss 2.301528, test error 89.25
# Epoch   100, train loss 1.696542, train error 60.05,  test loss 1.512275, test error 58.88
# Epoch   200, train loss 1.680957, train error 59.45,  test loss 1.521370, test error 58.22
# Epoch   300, train loss 1.674163, train error 59.70,  test loss 1.516819, test error 58.15
# Epoch   400, train loss 1.671569, train error 59.40,  test loss 1.513840, test error 58.67
# Epoch   500, train loss 1.665514, train error 59.83,  test loss 1.520944, test error 58.35
# Epoch   600, train loss 1.667438, train error 59.78,  test loss 1.537958, test error 58.85
# Epoch   700, train loss 1.655087, train error 59.47,  test loss 1.534982, test error 58.38
# Epoch   800, train loss 1.651468, train error 59.60,  test loss 1.537317, test error 58.70
# Epoch   900, train loss 1.650692, train error 59.58,  test loss 1.543179, test error 58.83
# Training model with   8 hidden variables
# Epoch     0, train loss 2.272320, train error 84.97,  test loss 2.256961, test error 83.65
# Epoch   100, train loss 1.644244, train error 58.22,  test loss 1.495077, test error 58.40
# Epoch   200, train loss 1.588589, train error 56.15,  test loss 1.462062, test error 56.10
# Epoch   300, train loss 1.569649, train error 55.88,  test loss 1.477821, test error 56.03
# Epoch   400, train loss 1.566314, train error 55.58,  test loss 1.479853, test error 55.95
# Epoch   500, train loss 1.547969, train error 55.17,  test loss 1.474172, test error 55.58
# Epoch   600, train loss 1.548531, train error 54.90,  test loss 1.482702, test error 56.25
# Epoch   700, train loss 1.541385, train error 54.97,  test loss 1.480640, test error 56.33
# Epoch   800, train loss 1.543350, train error 55.05,  test loss 1.483062, test error 55.88
# Epoch   900, train loss 1.539158, train error 54.67,  test loss 1.481811, test error 55.60
# Training model with  10 hidden variables
# Epoch     0, train loss 2.274689, train error 86.03,  test loss 2.268171, test error 86.22
# Epoch   100, train loss 1.486413, train error 49.78,  test loss 1.342312, test error 49.30
# Epoch   200, train loss 1.449462, train error 49.20,  test loss 1.341396, test error 48.78
# Epoch   300, train loss 1.432831, train error 48.28,  test loss 1.356186, test error 49.33
# Epoch   400, train loss 1.430359, train error 47.88,  test loss 1.366452, test error 49.35
# Epoch   500, train loss 1.414607, train error 47.65,  test loss 1.375466, test error 49.70
# Epoch   600, train loss 1.412619, train error 47.58,  test loss 1.376251, test error 50.00
# Epoch   700, train loss 1.407022, train error 47.45,  test loss 1.388155, test error 50.20
# Epoch   800, train loss 1.402674, train error 48.05,  test loss 1.385361, test error 49.55
# Epoch   900, train loss 1.405328, train error 47.70,  test loss 1.396909, test error 50.83
# Training model with  14 hidden variables
# Epoch     0, train loss 2.304498, train error 88.88,  test loss 2.311577, test error 87.85
# Epoch   100, train loss 1.480549, train error 50.08,  test loss 1.342021, test error 50.72
# Epoch   200, train loss 1.362739, train error 45.53,  test loss 1.285026, test error 47.05
# Epoch   300, train loss 1.330264, train error 44.40,  test loss 1.310750, test error 47.25
# Epoch   400, train loss 1.308550, train error 42.85,  test loss 1.333669, test error 47.38
# Epoch   500, train loss 1.294423, train error 43.03,  test loss 1.358481, test error 48.72
# Epoch   600, train loss 1.282597, train error 42.17,  test loss 1.356181, test error 48.50
# Epoch   700, train loss 1.273396, train error 42.65,  test loss 1.370091, test error 48.45
# Epoch   800, train loss 1.272075, train error 41.70,  test loss 1.401587, test error 49.53
# Epoch   900, train loss 1.263339, train error 41.53,  test loss 1.409930, test error 48.88
# Training model with  18 hidden variables
# Epoch     0, train loss 2.211122, train error 81.40,  test loss 2.173596, test error 80.38
# Epoch   100, train loss 1.356293, train error 44.67,  test loss 1.262434, test error 46.78
# Epoch   200, train loss 1.264680, train error 40.85,  test loss 1.292522, test error 47.70
# Epoch   300, train loss 1.224598, train error 39.62,  test loss 1.337032, test error 48.10
# Epoch   400, train loss 1.195876, train error 39.58,  test loss 1.383083, test error 48.15
# Epoch   500, train loss 1.171512, train error 38.50,  test loss 1.401872, test error 48.12
# Epoch   600, train loss 1.162155, train error 38.25,  test loss 1.443365, test error 48.95
# Epoch   700, train loss 1.147105, train error 37.62,  test loss 1.464876, test error 49.58
# Epoch   800, train loss 1.147869, train error 37.47,  test loss 1.505693, test error 50.30
# Epoch   900, train loss 1.137582, train error 37.53,  test loss 1.536636, test error 50.30
# Training model with  22 hidden variables
# Epoch     0, train loss 2.202806, train error 82.50,  test loss 2.165206, test error 81.72
# Epoch   100, train loss 1.332400, train error 44.08,  test loss 1.366935, test error 50.60
# Epoch   200, train loss 1.210516, train error 39.92,  test loss 1.418657, test error 50.75
# Epoch   300, train loss 1.153253, train error 37.75,  test loss 1.469151, test error 51.30
# Epoch   400, train loss 1.120264, train error 37.28,  test loss 1.523657, test error 51.62
# Epoch   500, train loss 1.097825, train error 36.72,  test loss 1.571045, test error 51.40
# Epoch   600, train loss 1.080472, train error 36.25,  test loss 1.626382, test error 52.75
# Epoch   700, train loss 1.062289, train error 35.35,  test loss 1.653536, test error 52.47
# Epoch   800, train loss 1.056992, train error 35.18,  test loss 1.697644, test error 52.15
# Epoch   900, train loss 1.047720, train error 35.68,  test loss 1.726359, test error 52.72
# Training model with  26 hidden variables
# Epoch     0, train loss 2.140272, train error 78.50,  test loss 2.099132, test error 78.05
# Epoch   100, train loss 1.209282, train error 39.83,  test loss 1.278214, test error 48.08
# Epoch   200, train loss 1.051778, train error 35.43,  test loss 1.420750, test error 49.45
# Epoch   300, train loss 0.987769, train error 33.80,  test loss 1.575511, test error 50.83
# Epoch   400, train loss 0.935887, train error 31.78,  test loss 1.673605, test error 51.53
# Epoch   500, train loss 0.889669, train error 30.28,  test loss 1.777486, test error 52.38
# Epoch   600, train loss 0.859736, train error 29.45,  test loss 1.833328, test error 52.10
# Epoch   700, train loss 0.852781, train error 28.90,  test loss 1.931453, test error 52.95
# Epoch   800, train loss 0.822978, train error 28.12,  test loss 2.008863, test error 53.85
# Epoch   900, train loss 0.826567, train error 28.68,  test loss 2.111809, test error 54.30
# Training model with  30 hidden variables
# Epoch     0, train loss 2.149507, train error 78.57,  test loss 2.091180, test error 76.88
# Epoch   100, train loss 1.126774, train error 36.50,  test loss 1.343728, test error 49.65
# Epoch   200, train loss 0.952242, train error 32.10,  test loss 1.540120, test error 51.60
# Epoch   300, train loss 0.878860, train error 29.45,  test loss 1.727705, test error 52.58
# Epoch   400, train loss 0.789606, train error 25.97,  test loss 1.872767, test error 54.00
# Epoch   500, train loss 0.766976, train error 26.32,  test loss 2.105579, test error 55.75
# Epoch   600, train loss 0.749970, train error 26.20,  test loss 2.227524, test error 55.62
# Epoch   700, train loss 0.728713, train error 25.57,  test loss 2.313399, test error 56.00
# Epoch   800, train loss 0.696878, train error 23.88,  test loss 2.383602, test error 55.38
# Epoch   900, train loss 0.697078, train error 24.95,  test loss 2.540889, test error 56.35
# Training model with  35 hidden variables
# Epoch     0, train loss 2.186969, train error 81.57,  test loss 2.151033, test error 80.57
# Epoch   100, train loss 1.054306, train error 34.50,  test loss 1.358852, test error 48.75
# Epoch   200, train loss 0.827828, train error 28.18,  test loss 1.656675, test error 51.28
# Epoch   300, train loss 0.721154, train error 24.15,  test loss 1.975095, test error 53.15
# Epoch   400, train loss 0.629735, train error 21.45,  test loss 2.245861, test error 53.80
# Epoch   500, train loss 0.592916, train error 21.38,  test loss 2.549472, test error 54.38
# Epoch   600, train loss 0.532852, train error 18.30,  test loss 2.845763, test error 54.72
# Epoch   700, train loss 0.518112, train error 18.50,  test loss 3.175242, test error 54.72
# Epoch   800, train loss 0.496762, train error 17.32,  test loss 3.408053, test error 55.97
# Epoch   900, train loss 0.471269, train error 16.38,  test loss 3.673644, test error 56.85
# Training model with  40 hidden variables
# Epoch     0, train loss 2.199666, train error 81.30,  test loss 2.182041, test error 81.25
# Epoch   100, train loss 0.931979, train error 29.53,  test loss 1.378117, test error 48.25
# Epoch   200, train loss 0.656250, train error 21.40,  test loss 1.865788, test error 52.25
# Epoch   300, train loss 0.509484, train error 16.80,  test loss 2.441312, test error 53.72
# Epoch   400, train loss 0.436331, train error 15.47,  test loss 3.204684, test error 55.58
# Epoch   500, train loss 0.329191, train error 10.75,  test loss 3.885198, test error 55.20
# Epoch   600, train loss 0.304721, train error 10.93,  test loss 4.776871, test error 56.47
# Epoch   700, train loss 0.264831, train error 9.53,  test loss 5.449798, test error 56.05
# Epoch   800, train loss 0.273472, train error 9.65,  test loss 6.270006, test error 57.15
# Epoch   900, train loss 0.269720, train error 9.65,  test loss 6.960645, test error 56.75
# Training model with  45 hidden variables
# Epoch     0, train loss 2.157408, train error 79.75,  test loss 2.130169, test error 78.25
# Epoch   100, train loss 0.842704, train error 27.28,  test loss 1.542759, test error 51.35
# Epoch   200, train loss 0.498441, train error 14.93,  test loss 2.335259, test error 54.35
# Epoch   300, train loss 0.319713, train error 9.93,  test loss 3.516355, test error 56.60
# Epoch   400, train loss 0.274778, train error 9.45,  test loss 4.807367, test error 56.42
# Epoch   500, train loss 0.175572, train error 5.25,  test loss 6.208881, test error 57.85
# Epoch   600, train loss 0.121292, train error 3.97,  test loss 7.544795, test error 58.53
# Epoch   700, train loss 0.019653, train error 0.03,  test loss 8.874844, test error 58.05
# Epoch   800, train loss 0.009946, train error 0.00,  test loss 9.829068, test error 58.08
# Epoch   900, train loss 0.007064, train error 0.00,  test loss 10.463954, test error 58.30
# Training model with  50 hidden variables
# Epoch     0, train loss 2.088287, train error 77.72,  test loss 2.030497, test error 77.32
# Epoch   100, train loss 0.717166, train error 21.70,  test loss 1.546947, test error 50.08
# Epoch   200, train loss 0.338732, train error 9.82,  test loss 2.526740, test error 52.67
# Epoch   300, train loss 0.171435, train error 4.75,  test loss 3.956903, test error 54.47
# Epoch   400, train loss 0.034770, train error 0.05,  test loss 5.429772, test error 54.25
# Epoch   500, train loss 0.013148, train error 0.00,  test loss 6.362268, test error 54.35
# Epoch   600, train loss 0.008117, train error 0.00,  test loss 6.969382, test error 54.40
# Epoch   700, train loss 0.005791, train error 0.00,  test loss 7.414359, test error 54.20
# Epoch   800, train loss 0.004521, train error 0.00,  test loss 7.769194, test error 54.05
# Epoch   900, train loss 0.003616, train error 0.00,  test loss 8.066650, test error 54.08
# Training model with  55 hidden variables
# Epoch     0, train loss 2.085112, train error 77.78,  test loss 2.055747, test error 77.30
# Epoch   100, train loss 0.635996, train error 19.53,  test loss 1.676798, test error 51.97
# Epoch   200, train loss 0.236664, train error 6.10,  test loss 3.063254, test error 55.12
# Epoch   300, train loss 0.042960, train error 0.05,  test loss 4.751924, test error 54.65
# Epoch   400, train loss 0.014954, train error 0.00,  test loss 5.832300, test error 54.85
# Epoch   500, train loss 0.008688, train error 0.00,  test loss 6.473631, test error 55.03
# Epoch   600, train loss 0.005934, train error 0.00,  test loss 6.939840, test error 55.05
# Epoch   700, train loss 0.004446, train error 0.00,  test loss 7.291321, test error 55.15
# Epoch   800, train loss 0.003520, train error 0.00,  test loss 7.579687, test error 55.17
# Epoch   900, train loss 0.002884, train error 0.00,  test loss 7.826666, test error 55.15
# Training model with  60 hidden variables
# Epoch     0, train loss 2.115049, train error 77.38,  test loss 2.079520, test error 77.65
# Epoch   100, train loss 0.549790, train error 16.82,  test loss 1.903010, test error 53.92
# Epoch   200, train loss 0.112340, train error 1.32,  test loss 3.692275, test error 56.95
# Epoch   300, train loss 0.019930, train error 0.00,  test loss 5.159450, test error 56.83
# Epoch   400, train loss 0.009549, train error 0.00,  test loss 5.915572, test error 56.78
# Epoch   500, train loss 0.006110, train error 0.00,  test loss 6.410086, test error 56.85
# Epoch   600, train loss 0.004368, train error 0.00,  test loss 6.781571, test error 56.75
# Epoch   700, train loss 0.003357, train error 0.00,  test loss 7.067132, test error 56.83
# Epoch   800, train loss 0.002696, train error 0.00,  test loss 7.315516, test error 56.95
# Epoch   900, train loss 0.002238, train error 0.00,  test loss 7.522730, test error 56.85
# Training model with  70 hidden variables
# Epoch     0, train loss 2.043981, train error 74.80,  test loss 1.972963, test error 74.15
# Epoch   100, train loss 0.359006, train error 8.53,  test loss 1.945057, test error 51.30
# Epoch   200, train loss 0.033084, train error 0.00,  test loss 3.681568, test error 53.47
# Epoch   300, train loss 0.010621, train error 0.00,  test loss 4.488859, test error 53.40
# Epoch   400, train loss 0.005943, train error 0.00,  test loss 4.934243, test error 53.42
# Epoch   500, train loss 0.004006, train error 0.00,  test loss 5.259492, test error 53.40
# Epoch   600, train loss 0.002970, train error 0.00,  test loss 5.503689, test error 53.55
# Epoch   700, train loss 0.002329, train error 0.00,  test loss 5.692375, test error 53.35
# Epoch   800, train loss 0.001902, train error 0.00,  test loss 5.856318, test error 53.47
# Epoch   900, train loss 0.001602, train error 0.00,  test loss 5.997776, test error 53.47
# Training model with  80 hidden variables
# Epoch     0, train loss 2.057559, train error 76.72,  test loss 2.009079, test error 76.15
# Epoch   100, train loss 0.224601, train error 3.82,  test loss 2.208157, test error 52.72
# Epoch   200, train loss 0.018798, train error 0.00,  test loss 3.619956, test error 53.55
# Epoch   300, train loss 0.007738, train error 0.00,  test loss 4.202390, test error 53.53
# Epoch   400, train loss 0.004593, train error 0.00,  test loss 4.553608, test error 53.83
# Epoch   500, train loss 0.003186, train error 0.00,  test loss 4.798509, test error 53.85
# Epoch   600, train loss 0.002413, train error 0.00,  test loss 4.993455, test error 53.88
# Epoch   700, train loss 0.001910, train error 0.00,  test loss 5.147245, test error 53.83
# Epoch   800, train loss 0.001575, train error 0.00,  test loss 5.279316, test error 53.85
# Epoch   900, train loss 0.001333, train error 0.00,  test loss 5.393235, test error 53.92
# Training model with  90 hidden variables
# Epoch     0, train loss 2.004768, train error 74.35,  test loss 1.923499, test error 73.88
# Epoch   100, train loss 0.122797, train error 0.65,  test loss 2.364011, test error 52.92
# Epoch   200, train loss 0.014048, train error 0.00,  test loss 3.422815, test error 53.03
# Epoch   300, train loss 0.006372, train error 0.00,  test loss 3.866952, test error 53.08
# Epoch   400, train loss 0.003919, train error 0.00,  test loss 4.137951, test error 53.08
# Epoch   500, train loss 0.002772, train error 0.00,  test loss 4.335915, test error 53.17
# Epoch   600, train loss 0.002113, train error 0.00,  test loss 4.490199, test error 53.08
# Epoch   700, train loss 0.001694, train error 0.00,  test loss 4.617845, test error 53.25
# Epoch   800, train loss 0.001405, train error 0.00,  test loss 4.726673, test error 53.28
# Epoch   900, train loss 0.001195, train error 0.00,  test loss 4.820006, test error 53.15
# Training model with 100 hidden variables
# Epoch     0, train loss 2.028393, train error 75.57,  test loss 1.928803, test error 73.78
# Epoch   100, train loss 0.089822, train error 0.18,  test loss 2.328549, test error 52.78
# Epoch   200, train loss 0.011575, train error 0.00,  test loss 3.165487, test error 52.42
# Epoch   300, train loss 0.005433, train error 0.00,  test loss 3.531669, test error 52.30
# Epoch   400, train loss 0.003395, train error 0.00,  test loss 3.756982, test error 52.30
# Epoch   500, train loss 0.002421, train error 0.00,  test loss 3.925869, test error 52.45
# Epoch   600, train loss 0.001858, train error 0.00,  test loss 4.058209, test error 52.47
# Epoch   700, train loss 0.001496, train error 0.00,  test loss 4.165949, test error 52.40
# Epoch   800, train loss 0.001244, train error 0.00,  test loss 4.257356, test error 52.33
# Epoch   900, train loss 0.001060, train error 0.00,  test loss 4.338306, test error 52.38
# Training model with 120 hidden variables
# Epoch     0, train loss 1.967829, train error 73.95,  test loss 1.883280, test error 73.07
# Epoch   100, train loss 0.047900, train error 0.00,  test loss 2.278902, test error 51.15
# Epoch   200, train loss 0.009335, train error 0.00,  test loss 2.890505, test error 51.08
# Epoch   300, train loss 0.004656, train error 0.00,  test loss 3.172879, test error 50.83
# Epoch   400, train loss 0.002981, train error 0.00,  test loss 3.351776, test error 50.97
# Epoch   500, train loss 0.002155, train error 0.00,  test loss 3.485919, test error 50.80
# Epoch   600, train loss 0.001667, train error 0.00,  test loss 3.591578, test error 51.00
# Epoch   700, train loss 0.001348, train error 0.00,  test loss 3.680243, test error 50.88
# Epoch   800, train loss 0.001126, train error 0.00,  test loss 3.753548, test error 50.90
# Epoch   900, train loss 0.000963, train error 0.00,  test loss 3.818399, test error 50.85
# Training model with 140 hidden variables
# Epoch     0, train loss 1.975527, train error 73.07,  test loss 1.890591, test error 73.80
# Epoch   100, train loss 0.035673, train error 0.00,  test loss 2.277125, test error 50.50
# Epoch   200, train loss 0.007979, train error 0.00,  test loss 2.766052, test error 50.17
# Epoch   300, train loss 0.004113, train error 0.00,  test loss 2.994958, test error 50.15
# Epoch   400, train loss 0.002679, train error 0.00,  test loss 3.148925, test error 50.15
# Epoch   500, train loss 0.001951, train error 0.00,  test loss 3.264975, test error 50.15
# Epoch   600, train loss 0.001517, train error 0.00,  test loss 3.356601, test error 50.10
# Epoch   700, train loss 0.001233, train error 0.00,  test loss 3.431500, test error 50.12
# Epoch   800, train loss 0.001033, train error 0.00,  test loss 3.496361, test error 50.03
# Epoch   900, train loss 0.000886, train error 0.00,  test loss 3.553078, test error 50.00
# Training model with 160 hidden variables
# Epoch     0, train loss 1.953889, train error 72.28,  test loss 1.886303, test error 72.88
# Epoch   100, train loss 0.028554, train error 0.00,  test loss 2.171205, test error 48.80
# Epoch   200, train loss 0.007193, train error 0.00,  test loss 2.597668, test error 49.15
# Epoch   300, train loss 0.003782, train error 0.00,  test loss 2.805459, test error 49.15
# Epoch   400, train loss 0.002482, train error 0.00,  test loss 2.942448, test error 49.00
# Epoch   500, train loss 0.001816, train error 0.00,  test loss 3.044984, test error 49.00
# Epoch   600, train loss 0.001417, train error 0.00,  test loss 3.126545, test error 48.97
# Epoch   700, train loss 0.001154, train error 0.00,  test loss 3.194150, test error 48.90
# Epoch   800, train loss 0.000968, train error 0.00,  test loss 3.252893, test error 48.97
# Epoch   900, train loss 0.000831, train error 0.00,  test loss 3.303085, test error 48.70
# Training model with 180 hidden variables
# Epoch     0, train loss 1.936712, train error 71.12,  test loss 1.849990, test error 70.85
# Epoch   100, train loss 0.025014, train error 0.00,  test loss 2.066137, test error 48.95
# Epoch   200, train loss 0.006642, train error 0.00,  test loss 2.426590, test error 48.95
# Epoch   300, train loss 0.003545, train error 0.00,  test loss 2.604729, test error 48.90
# Epoch   400, train loss 0.002344, train error 0.00,  test loss 2.726573, test error 48.83
# Epoch   500, train loss 0.001726, train error 0.00,  test loss 2.819057, test error 48.70
# Epoch   600, train loss 0.001351, train error 0.00,  test loss 2.892535, test error 48.83
# Epoch   700, train loss 0.001104, train error 0.00,  test loss 2.954344, test error 48.85
# Epoch   800, train loss 0.000928, train error 0.00,  test loss 3.006120, test error 48.88
# Epoch   900, train loss 0.000797, train error 0.00,  test loss 3.052435, test error 48.83
# Training model with 200 hidden variables
# Epoch     0, train loss 1.942720, train error 71.65,  test loss 1.857753, test error 72.68
# Epoch   100, train loss 0.021992, train error 0.00,  test loss 2.072608, test error 48.42
# Epoch   200, train loss 0.006114, train error 0.00,  test loss 2.399641, test error 48.28
# Epoch   300, train loss 0.003318, train error 0.00,  test loss 2.570232, test error 48.40
# Epoch   400, train loss 0.002215, train error 0.00,  test loss 2.686977, test error 48.40
# Epoch   500, train loss 0.001637, train error 0.00,  test loss 2.774622, test error 48.35
# Epoch   600, train loss 0.001286, train error 0.00,  test loss 2.845483, test error 48.28
# Epoch   700, train loss 0.001053, train error 0.00,  test loss 2.904466, test error 48.35
# Epoch   800, train loss 0.000887, train error 0.00,  test loss 2.954803, test error 48.35
# Epoch   900, train loss 0.000763, train error 0.00,  test loss 2.999139, test error 48.33
# Training model with 250 hidden variables
# Epoch     0, train loss 1.905189, train error 69.00,  test loss 1.814497, test error 71.25
# Epoch   100, train loss 0.016635, train error 0.00,  test loss 1.976690, test error 47.78
# Epoch   200, train loss 0.005279, train error 0.00,  test loss 2.237905, test error 48.08
# Epoch   300, train loss 0.002954, train error 0.00,  test loss 2.375222, test error 48.12
# Epoch   400, train loss 0.001998, train error 0.00,  test loss 2.469375, test error 48.15
# Epoch   500, train loss 0.001488, train error 0.00,  test loss 2.540946, test error 48.08
# Epoch   600, train loss 0.001175, train error 0.00,  test loss 2.597772, test error 48.05
# Epoch   700, train loss 0.000965, train error 0.00,  test loss 2.645955, test error 48.17
# Epoch   800, train loss 0.000816, train error 0.00,  test loss 2.686836, test error 48.20
# Epoch   900, train loss 0.000704, train error 0.00,  test loss 2.723126, test error 48.17
# Training model with 300 hidden variables
# Epoch     0, train loss 1.913491, train error 68.72,  test loss 1.860408, test error 71.82
# Epoch   100, train loss 0.014208, train error 0.00,  test loss 1.880939, test error 48.10
# Epoch   200, train loss 0.004780, train error 0.00,  test loss 2.106834, test error 47.72
# Epoch   300, train loss 0.002713, train error 0.00,  test loss 2.225792, test error 47.60
# Epoch   400, train loss 0.001851, train error 0.00,  test loss 2.308059, test error 47.75
# Epoch   500, train loss 0.001386, train error 0.00,  test loss 2.370897, test error 47.75
# Epoch   600, train loss 0.001099, train error 0.00,  test loss 2.422247, test error 47.75
# Epoch   700, train loss 0.000905, train error 0.00,  test loss 2.465394, test error 47.75
# Epoch   800, train loss 0.000766, train error 0.00,  test loss 2.502697, test error 47.67
# Epoch   900, train loss 0.000662, train error 0.00,  test loss 2.535048, test error 47.67
# Training model with 400 hidden variables
# Epoch     0, train loss 1.897388, train error 67.82,  test loss 1.852872, test error 71.12
# Epoch   100, train loss 0.011751, train error 0.00,  test loss 1.832040, test error 47.10
# Epoch   200, train loss 0.004178, train error 0.00,  test loss 2.018492, test error 46.97
# Epoch   300, train loss 0.002421, train error 0.00,  test loss 2.120232, test error 46.95
# Epoch   400, train loss 0.001666, train error 0.00,  test loss 2.190252, test error 47.05
# Epoch   500, train loss 0.001255, train error 0.00,  test loss 2.244012, test error 46.97
# Epoch   600, train loss 0.001000, train error 0.00,  test loss 2.287647, test error 46.92
# Epoch   700, train loss 0.000826, train error 0.00,  test loss 2.324663, test error 46.80
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.355995, test error 46.85
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.383490, test error 46.72

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
